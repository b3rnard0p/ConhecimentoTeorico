# %%
AMOSTRA= f"amostras710.csv"

# %%
import pandas as pd

df = pd.read_csv(AMOSTRA)

print("--- Primeiras 5 linhas ---")
display(df.head())

print("\n--- Últimas 5 linhas ---")
display(df.tail())
# Out:
# --- Primeiras 5 linhas ---
#                                     cod_imovel   latitude  longitude  \
# 0  AC-1200013-0065DD410D8B4D74884D124552595A75 -10.065699 -67.099232
# 1  AC-1200013-008511C82A7D491C8FE9A77F156515BC  -9.766742 -67.135746
# 2  AC-1200013-012F582E360D4D95B8EE515A7BFF367D  -9.917798 -66.662608
# 3  AC-1200013-01A560FBDDFF49BBA34A961576C7159C  -9.864668 -66.766198
# 4  AC-1200013-01B3514760CF46D28DD72FF7B6E01D3E  -9.697995 -67.129506
#
#    altitude_m  precipitacao_anual_mm  temperatura_media_c  ph_solo  ctc_solo  \
# 0      165.81                 1778.0                 25.7      4.8      86.0
# 1      140.45                 1778.0                 25.7      4.8      92.0
# 2      131.79                 1778.0                 25.7      4.9      61.0
# 3      148.72                 1778.0                 25.7      4.8      81.0
# 4      130.97                 1829.0                 25.7      4.8      82.0
#
#   legenda_solo  mos_solo  declividade_perc  umidade_relativa_perc  \
# 0         PVAd      39.0              2.50                   84.8
# 1         PVAd      32.0              2.83                   84.8
# 2         PVAd      30.0              4.82                   84.8
# 3         PVAd      35.0              6.60                   84.8
# 4         PVAd      33.0              2.26                   85.1
#
#    radiacao_solar_mj erosao_classe  distancia_agua_m cultura_ideal_rotulo
# 0               17.1         Média              23.7               Buriti
# 1               17.0         Média             480.2               Banana
# 2               17.0         Média              48.9              Guaraná
# 3               17.0         Média             449.7                 Cará
# 4               17.0         Média             264.1               Banana
# --- Últimas 5 linhas ---
#                                       cod_imovel  latitude  longitude  \
# 704  TO-1700251-0F5AE91371F04AF89749E3D821E339E0 -9.629756 -49.150933
# 705  TO-1700251-101E7B097D97443AA266549325DB1741 -9.517708 -49.226682
# 706  TO-1700251-1029A87BD8D64488AB19BDD20B6A246C -9.695426 -49.118411
# 707  TO-1700251-1040BF4854394B6A8A525AAD131B32A5 -9.619685 -49.187555
# 708  TO-1700251-1041DFD7B0C541B19D05B8098B664C79 -9.695648 -49.220533
#
#      altitude_m  precipitacao_anual_mm  temperatura_media_c  ph_solo  \
# 704      233.64                 1617.0                 27.3      5.1
# 705      217.25                 1617.0                 27.3      4.9
# 706      265.17                 1617.0                 27.3      5.1
# 707      233.99                 1617.0                 27.3      5.1
# 708      233.58                 1617.0                 27.3      5.0
#
#      ctc_solo legenda_solo  mos_solo  declividade_perc  umidade_relativa_perc  \
# 704      69.0          FFc      40.0              2.80                   69.2
# 705      73.0         GXbd      40.0              3.73                   69.2
# 706      66.0          FFc      50.0              2.74                   69.2
# 707      70.0          FFc      38.0              3.20                   69.2
# 708      73.0          FFc      39.0              2.35                   69.2
#
#      radiacao_solar_mj erosao_classe  distancia_agua_m cultura_ideal_rotulo
# 704               19.4    Muito alta             182.5             Gengibre
# 705               19.4         Média             147.8             Gengibre
# 706               19.4         Média             392.5     Arroz (sequeiro)
# 707               19.4         Média              93.9             Gengibre
# 708               19.4         Média             301.0     Arroz (sequeiro)

# %%
FEATURES = [
    "altitude_m",
    "precipitacao_anual_mm",
    "temperatura_media_c",
    "ph_solo",
    "ctc_solo",
    "legenda_solo",
    "mos_solo",
    "declividade_perc",
    "umidade_relativa_perc",
    "radiacao_solar_mj",
    "erosao_classe",
    "distancia_agua_m",
]

TARGET = "cultura_ideal_rotulo"

# %%
from sklearn.preprocessing import LabelEncoder

df_ml = df.copy()

le_solo = LabelEncoder()
le_erosao = LabelEncoder()

df_ml["legenda_solo"] = le_solo.fit_transform(df_ml["legenda_solo"].astype(str))

df_ml["erosao_classe"] = le_erosao.fit_transform(df_ml["erosao_classe"].astype(str))

mapa_solo = dict(zip(le_solo.classes_, le_solo.transform(le_solo.classes_)))
mapa_erosao = dict(zip(le_erosao.classes_, le_erosao.transform(le_erosao.classes_)))

print("\n--- Mapeamento: Legenda Solo ---")
for texto, num in list(mapa_solo.items())[:5]:
    print(f"{num}: {texto}")
print("...")

print("\n--- Mapeamento: Erosão Classe ---")
for texto, num in mapa_erosao.items():
    print(f"{num}: {texto}")

print("\n--- Resumo Final ---")
print("Amostras:", len(df_ml))
print("Classes de cultura mantidas em texto:", df_ml[TARGET].nunique())
# Out:
# --- Mapeamento: Legenda Solo ---
# 0: AGUA
# 1: CXbd
# 2: FFc
# 3: FXd
# 4: GXbd
# ...
#
# --- Mapeamento: Erosão Classe ---
# 0: Alta
# 1: Baixa
# 2: Muito alta
# 3: Muito baixa
# 4: Média
# 5: Área urbana
#
# --- Resumo Final ---
# Amostras: 709
# Classes de cultura mantidas em texto: 78

# %%
print("--- Primeiras 5 linhas ---")
display(df_ml.head())

print("\n--- Últimas 5 linhas ---")
display(df_ml.tail())
# Out:
# --- Primeiras 5 linhas ---
#                                     cod_imovel   latitude  longitude  \
# 0  AC-1200013-0065DD410D8B4D74884D124552595A75 -10.065699 -67.099232
# 1  AC-1200013-008511C82A7D491C8FE9A77F156515BC  -9.766742 -67.135746
# 2  AC-1200013-012F582E360D4D95B8EE515A7BFF367D  -9.917798 -66.662608
# 3  AC-1200013-01A560FBDDFF49BBA34A961576C7159C  -9.864668 -66.766198
# 4  AC-1200013-01B3514760CF46D28DD72FF7B6E01D3E  -9.697995 -67.129506
#
#    altitude_m  precipitacao_anual_mm  temperatura_media_c  ph_solo  ctc_solo  \
# 0      165.81                 1778.0                 25.7      4.8      86.0
# 1      140.45                 1778.0                 25.7      4.8      92.0
# 2      131.79                 1778.0                 25.7      4.9      61.0
# 3      148.72                 1778.0                 25.7      4.8      81.0
# 4      130.97                 1829.0                 25.7      4.8      82.0
#
#    legenda_solo  mos_solo  declividade_perc  umidade_relativa_perc  \
# 0            12      39.0              2.50                   84.8
# 1            12      32.0              2.83                   84.8
# 2            12      30.0              4.82                   84.8
# 3            12      35.0              6.60                   84.8
# 4            12      33.0              2.26                   85.1
#
#    radiacao_solar_mj  erosao_classe  distancia_agua_m cultura_ideal_rotulo
# 0               17.1              4              23.7               Buriti
# 1               17.0              4             480.2               Banana
# 2               17.0              4              48.9              Guaraná
# 3               17.0              4             449.7                 Cará
# 4               17.0              4             264.1               Banana
# --- Últimas 5 linhas ---
#                                       cod_imovel  latitude  longitude  \
# 704  TO-1700251-0F5AE91371F04AF89749E3D821E339E0 -9.629756 -49.150933
# 705  TO-1700251-101E7B097D97443AA266549325DB1741 -9.517708 -49.226682
# 706  TO-1700251-1029A87BD8D64488AB19BDD20B6A246C -9.695426 -49.118411
# 707  TO-1700251-1040BF4854394B6A8A525AAD131B32A5 -9.619685 -49.187555
# 708  TO-1700251-1041DFD7B0C541B19D05B8098B664C79 -9.695648 -49.220533
#
#      altitude_m  precipitacao_anual_mm  temperatura_media_c  ph_solo  \
# 704      233.64                 1617.0                 27.3      5.1
# 705      217.25                 1617.0                 27.3      4.9
# 706      265.17                 1617.0                 27.3      5.1
# 707      233.99                 1617.0                 27.3      5.1
# 708      233.58                 1617.0                 27.3      5.0
#
#      ctc_solo  legenda_solo  mos_solo  declividade_perc  \
# 704      69.0             2      40.0              2.80
# 705      73.0             4      40.0              3.73
# 706      66.0             2      50.0              2.74
# 707      70.0             2      38.0              3.20
# 708      73.0             2      39.0              2.35
#
#      umidade_relativa_perc  radiacao_solar_mj  erosao_classe  \
# 704                   69.2               19.4              2
# 705                   69.2               19.4              4
# 706                   69.2               19.4              4
# 707                   69.2               19.4              4
# 708                   69.2               19.4              4
#
#      distancia_agua_m cultura_ideal_rotulo
# 704             182.5             Gengibre
# 705             147.8             Gengibre
# 706             392.5     Arroz (sequeiro)
# 707              93.9             Gengibre
# 708             301.0     Arroz (sequeiro)

# %%
print(df_ml[TARGET].value_counts())
# Out:
# cultura_ideal_rotulo
# Mandioca                     46
# Cúrcuma (açafrão)            44
# Gergelim                     41
# Arroz (sequeiro)             36
# Banana                       35
#                              ..
# Girassol                      1
# Milho (2ª safra/safrinha)     1
# Orégano                       1
# Cana-forrageira               1
# Quiabo                        1
# Name: count, Length: 78, dtype: int64

# %%
contagem_classes = df_ml[TARGET].value_counts()
classes_validas = contagem_classes[contagem_classes >= 2].index
df_ml = df_ml[df_ml[TARGET].isin(classes_validas)]

# %%
import pycaret
from pycaret.classification import setup, models,compare_models, pull

setup(
    data=df_ml[FEATURES + [TARGET]],
    target=TARGET,
    session_id=42,
    train_size=0.8,
    fold=5,
    n_jobs=-1,
    use_gpu=False,
    verbose=False,
    fix_imbalance=False,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.9,
    feature_selection=True,
    n_features_to_select=0.8,
    normalize=True,
)

best_models = compare_models(
    sort="F1",
    n_select=len(models()),
    turbo=False,
)

leaderboard = pull()

pd.set_option('display.max_rows', None)

display(leaderboard)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             12:48:29
# Status     . . . . . . . . . . . . . . . . . .      Fitting 5 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# Processing:   0%|          | 0/89 [00:00<?, ?it/s]
